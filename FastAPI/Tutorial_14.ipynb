# %% [markdown]
# # FastAPI Tutorial 14 - DELETE Requests

# %% [markdown]
# In this tutorial, we will explore how to use DELETE requests in FastAPI to remove resources from our application.

# %%
@app.delete("/shipment")
def delete_shipment(id: int) -> dict[str, str]:
    shipments.pop(id)

    return {"detail": f"Shipment with ID #{id} has been deleted."}
